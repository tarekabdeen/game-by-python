# %%
def even_odd_game():
    print("when you want to exit press x")
    while True:
        num=input("please enter a number:")
        if(num=="x"):
            break
        else:
                try:
                    num=int(num)
                    if x % 2==0:
                        print("even")
                    else:
                            print("odd")
                except:
                    print("invalid")
                            
even_odd_game()

# %%
def multiplication_game():
    print("wellcom in multiplication game")
    print("when you want to close the game press x")
    while True:
        start=input("please enter a start number:")
        end=input("please enter end number:")
        if start=='x' or end=='x':
            break
        try:
            start_number=int(start)
            end_number=int(end)
            for num in range(start_number,end_number+1):
                for i in range(0,13):
                    print(num,'x',i,'=',num*i)
                print("-"*50)
        except:
                print("invalid try again")
multiplication_game()
# Out:
# wellcom in multiplication game
# when you want to close the game press x
# please enter a start number:3
# please enter end number:5
# 3 x 0 = 0
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 3 x 11 = 33
# 3 x 12 = 36
# --------------------------------------------------
# 4 x 0 = 0
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 4 x 11 = 44
# 4 x 12 = 48
# --------------------------------------------------
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 5 x 11 = 55
# 5 x 12 = 60
# --------------------------------------------------
# please enter a start number:3
# please enter end number:5
# 3 x 0 = 0
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# ...

# %%
def sum_average_game():
    print("wellcom in multiplication game")
    print("when you want to close the game press x")
    try:
        count=int(input("how many numbers would you like to sum:"))
        current_count=0
        sum=0
        while current_count<count:
            number=float(input("enter the number:"))
            sum+=number
            current_count+=1
            if number=='x':
                break
        print("sum of all numbers=",sum)
        print("average of all numbers=",sum/count)
    except:
        print("please enter avalid number")
sum_average_game()
# Out:
# wellcom in multiplication game
# when you want to close the game press x
# how many numbers would you like to sum:3
# enter the number:5
# enter the number:x
# please enter avalid number

# %%
class game:
    def __init__(self):
        print("wellcom in full game....^_^")
        print("choose your game from your collection")
        print("press[1] : play multiplication game")
        print("press[2] : play even odd game")
        print("press[3] :play sum average game")
        
        self.choices()
    def choices(self):
        while True:
                print("if you want to exit the application press 'x'")
                user_choice=input("enter your choice:")
                if user_choice.lower() == 'x':
                    break
                try :
                    user_choice=int(user_choice)
                    if user_choice == 1:
                        self.multiplication_game()
                    elif user_choice == 2:
                        self.even_odd_game()
                    elif user_choice == 3:
                        self.sum_average_game()
                    else:
                        print("choose from 1,2 or 3")
                except:
                    print("please a valid number")
    def multiplication_game(self):
        print("wellcom in multiplication game")
        print("when you want to close the game press x")
        while True:
            start=input("please enter a start number:")
            if start=='x':
                break
            try:
                start=int(start)
            except:
                print("please enter valid number")
                break
                end=input("enter the last number of the table:")
                try:
                    end=int(end)
                    if start<end:
                        temp=n1
                        n1=n2
                        n2=temp
                    for num in range(start,end+1):
                        for i in range(0,13):
                            print(num,'x',i,'=',num*i)
                    print("-"*50)
                except:
                    print("invalid try again")
    def even_odd_game(self):
        print("when you want to exit press x")
        while True:
            num=input("please enter a number:")
            if(num=="x"):
                break
            else:
                    try:
                        num=int(num)
                        if x % 2==0:
                            print("even")
                        else:
                            print("odd")
                    except:
                        print("invalid")
    def sum_average_game(self):
        print("wellcom in multiplication game")
        print("when you want to close the game press x")
        try:
            count=int(input("how many numbers would you like to sum:"))
            current_count=0
            sum=0
            while current_count<count:
                number=float(input("enter the number:"))
                sum+=number
                current_count+=1
                
            print("sum of all numbers=",sum)
            print("average of all numbers=",sum/count)
        except:
            print("please enter avalid number")
game1=game()
# Out:
# wellcom in full game....^_^
# choose your game from your collection
# press[1] : play multiplication game
# press[2] : play even odd game
# press[3] :play sum average game
# if you want to exit the application press 'x'
# enter your choice:1
# wellcom in multiplication game
# when you want to close the game press x
# please enter a start number:2
# please enter a start number:2
# please enter a start number:2
# please enter a start number:2
